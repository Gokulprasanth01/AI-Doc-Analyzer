# %%
import os
import PyPDF2
import pandas as pd

# Path to the directory containing PDFs
data_folder = r"D:\dataset\MSc DS"
data = []

def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
        return text

def get_document_type_from_filename(filename):
    # Extract the document type from the filename
    base_name = os.path.splitext(filename)[0]  # Remove the file extension
    parts = base_name.split('_')
    if len(parts) > 1:
        return parts[0]  # Return the document type
    return "Unknown"

for file_name in os.listdir(data_folder):
    if file_name.endswith('.pdf'):
        file_path = os.path.join(data_folder, file_name)
        extracted_text = extract_text_from_pdf(file_path)
        label = get_document_type_from_filename(file_name)
        data.append({"Document Filename": file_name, "Text": extracted_text, "Label": label})

df = pd.DataFrame(data)
df.to_csv("extracted_texts.csv", index=False)

# %%
import os
import pdfplumber
import pandas as pd

# Base folder path template with a placeholder for the last two digits
base_folder_template = 'D:/dataset/MSc DS/20320{}'

def extract_text_from_pdf(pdf_path):
    text = ''
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() or ''
    return text

def extract_label_from_filename(filename):
    base_name = os.path.splitext(filename)[0]
    parts = base_name.split('_')
    if len(parts) > 1:
        return parts[0]  # Return the document type
    return "Unknown"

def process_folder(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.pdf'):
            file_path = os.path.join(folder_path, file_name)
            extracted_text = extract_text_from_pdf(file_path)
            label = extract_label_from_filename(file_name)
            data.append({"Document Filename": file_name, "Text": extracted_text, "Label": label})
    return data

all_data = []

# Iterate through folders from 02 to 51, excluding folder 29
for i in range(2, 52):
    if i != 29 & 39:
        # Format the folder path with leading zeros for two digits
        folder_path = base_folder_template.format(f'{i:02}')
        if os.path.exists(folder_path):
            print(f'Processing folder: {folder_path}')
            folder_data = process_folder(folder_path)
            all_data.extend(folder_data)

# Create DataFrame and save to CSV
df = pd.DataFrame(all_data)
df.to_csv("extracted_texts.csv", index=False)
# Out:
# Processing folder: D:/dataset/MSc DS/2032002
# Processing folder: D:/dataset/MSc DS/2032003
# Processing folder: D:/dataset/MSc DS/2032004
# Processing folder: D:/dataset/MSc DS/2032006
# Processing folder: D:/dataset/MSc DS/2032007
# Processing folder: D:/dataset/MSc DS/2032008
# Processing folder: D:/dataset/MSc DS/2032009
# Processing folder: D:/dataset/MSc DS/2032010
# Processing folder: D:/dataset/MSc DS/2032011
# Processing folder: D:/dataset/MSc DS/2032012
# Processing folder: D:/dataset/MSc DS/2032013
# Processing folder: D:/dataset/MSc DS/2032014
# Processing folder: D:/dataset/MSc DS/2032015
# Processing folder: D:/dataset/MSc DS/2032016
# Processing folder: D:/dataset/MSc DS/2032017
# Processing folder: D:/dataset/MSc DS/2032018
# Processing folder: D:/dataset/MSc DS/2032019
# Processing folder: D:/dataset/MSc DS/2032020
# Processing folder: D:/dataset/MSc DS/2032021
# Processing folder: D:/dataset/MSc DS/2032022
# Processing folder: D:/dataset/MSc DS/2032023
# Processing folder: D:/dataset/MSc DS/2032024
# Processing folder: D:/dataset/MSc DS/2032025
# Processing folder: D:/dataset/MSc DS/2032026
# Processing folder: D:/dataset/MSc DS/2032027
# Processing folder: D:/dataset/MSc DS/2032028
# Processing folder: D:/dataset/MSc DS/2032029
# Processing folder: D:/dataset/MSc DS/2032030
# Processing folder: D:/dataset/MSc DS/2032031
# Processing folder: D:/dataset/MSc DS/2032032
# Processing folder: D:/dataset/MSc DS/2032033
# Processing folder: D:/dataset/MSc DS/2032034
# Processing folder: D:/dataset/MSc DS/2032035
# Processing folder: D:/dataset/MSc DS/2032036
# Processing folder: D:/dataset/MSc DS/2032037
# Processing folder: D:/dataset/MSc DS/2032038
# Processing folder: D:/dataset/MSc DS/2032040
# Processing folder: D:/dataset/MSc DS/2032041
# Processing folder: D:/dataset/MSc DS/2032042
# Processing folder: D:/dataset/MSc DS/2032043
# Processing folder: D:/dataset/MSc DS/2032044
# Processing folder: D:/dataset/MSc DS/2032045
# Processing folder: D:/dataset/MSc DS/2032046
# Processing folder: D:/dataset/MSc DS/2032047
# Processing folder: D:/dataset/MSc DS/2032048
# Processing folder: D:/dataset/MSc DS/2032049
# Processing folder: D:/dataset/MSc DS/2032050
# Processing folder: D:/dataset/MSc DS/2032051

# %%
import os
import PyPDF2
import pandas as pd
from pdf2image import convert_from_path
import pytesseract

# Path to Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\Gokul01\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"  # Update this path if needed

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file, using OCR if necessary."""
    text = ""
    
    try:
        # Try extracting text directly
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            for page in reader.pages:
                text += page.extract_text() or ''
        
        # If text extraction fails or is empty, use OCR
        if not text.strip():
            images = convert_from_path(pdf_path)
            for image in images:
                text += pytesseract.image_to_string(image)
    
    except Exception as e:
        print(f"Error processing {pdf_path}: {e}")
    
    return text

def extract_label_from_filename(filename):
    """Extract the label from the filename based on predefined patterns."""
    base_name = os.path.splitext(filename)[0]
    parts = base_name.split('_')
    if len(parts) > 1:
        return parts[0]  # Return the document type based on the filename pattern
    return "Unknown"

def process_folder(folder_path):
    """Process all PDFs in a given folder."""
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.pdf'):
            file_path = os.path.join(folder_path, file_name)
            extracted_text = extract_text_from_pdf(file_path)
            label = extract_label_from_filename(file_name)
            data.append({"Document Filename": file_name, "Text": extracted_text, "Label": label})
    return data

def process_folders(base_folder_path):
    """Process all PDFs in the subfolders of the base folder."""
    all_data = []
    
    # Iterate through folders
    for i in range(2, 52):
        if i not in (29, 39):  # Exclude folders 29 and 39
            folder_path = os.path.join(base_folder_path, f'20320{i:02}')
            if os.path.exists(folder_path):
                print(f'Processing folder: {folder_path}')
                folder_data = process_folder(folder_path)
                all_data.extend(folder_data)
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(all_data)
    csv_path = os.path.join(base_folder_path, "extracted_texts.csv")
    df.to_csv(csv_path, index=False)
    print(f"Data has been saved to {csv_path}")

if __name__ == "__main__":
    base_folder_path = r"D:\dataset\MSc DS"  # Replace with your directory path
    process_folders(base_folder_path)
# Out:
# Processing folder: D:\dataset\MSc DS\2032002
# Processing folder: D:\dataset\MSc DS\2032003
# Error processing D:\dataset\MSc DS\2032003\pan_card_2032003.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032004
# Error processing D:\dataset\MSc DS\2032004\aadhar_back_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Multiple definitions in dictionary at byte 0x87ee9 for key /Info
# Multiple definitions in dictionary at byte 0x87ef5 for key /Info
# Multiple definitions in dictionary at byte 0x87f01 for key /Info
# Multiple definitions in dictionary at byte 0x8aa6c for key /Info
# Error processing D:\dataset\MSc DS\2032004\birth_certificate_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\id_card_back_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\id_card_front_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_1_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Multiple definitions in dictionary at byte 0x8aa78 for key /Info
# Multiple definitions in dictionary at byte 0x8aa84 for key /Info
# Multiple definitions in dictionary at byte 0x8aa6c for key /Info
# Multiple definitions in dictionary at byte 0x8aa78 for key /Info
# Multiple definitions in dictionary at byte 0x8aa84 for key /Info
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_2_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_3_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_4_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_5_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_6_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_8_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032004\mark_sheet_9_2032004.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032005
# Processing folder: D:\dataset\MSc DS\2032006
# Error processing D:\dataset\MSc DS\2032006\aadhar_back_2032006.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032007
# Error processing D:\dataset\MSc DS\2032007\aadhar_back_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\aadhar_front_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\birth_certificate_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\id_card_back_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\mark_sheet_1_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\mark_sheet_3_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\mark_sheet_4_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\mark_sheet_5_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\mark_sheet_6_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032007\pan_card_2032007.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032008
# Error processing D:\dataset\MSc DS\2032008\aadhar_back_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\aadhar_front_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\birth_certificate_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\mark_sheet_1_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\mark_sheet_2_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\mark_sheet_3_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032008\pan_card_2032008.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032009
# Error processing D:\dataset\MSc DS\2032009\aadhar_back_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\aadhar_front_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\birth_certificate_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\id_card_back_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\id_card_front_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_1_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_2_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_4_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_5_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_6_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_7_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_8_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\mark_sheet_9_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032009\pan_card_2032009.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032010
# Error processing D:\dataset\MSc DS\2032010\aadhar_back_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\aadhar_front_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\birth_certificate_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\id_card_back_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\id_card_front_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_1_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_3_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_4_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_5_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_6_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_7_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_8_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\mark_sheet_9_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032010\pan_card_2032010.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032011
# Error processing D:\dataset\MSc DS\2032011\pan_card_2032011.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032012
# Error processing D:\dataset\MSc DS\2032012\pan_card_2032012.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032013
# Error processing D:\dataset\MSc DS\2032013\aadhar_back_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\aadhar_front_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\birth_certificate_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\id_card_back_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\id_card_front_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_1_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_2_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_3_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_4_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_5_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_6_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\mark_sheet_7_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032013\pan_card_2032013.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032014
# Error processing D:\dataset\MSc DS\2032014\aadhar_back_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\aadhar_front_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\birth_certificate_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\id_card_back_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\id_card_front_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_1_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_2_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_3_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_4_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_5_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_6_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_7_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_8_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\mark_sheet_9_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032014\pan_card_2032014.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032015
# Processing folder: D:\dataset\MSc DS\2032016
# Processing folder: D:\dataset\MSc DS\2032017
# Error processing D:\dataset\MSc DS\2032017\aadhar_back_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\aadhar_front_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\birth_certificate_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\id_card_back_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\id_card_front_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_1_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_2_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_3_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_4_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_5_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_6_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_7_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\mark_sheet_9_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032017\pan_card_2032017.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032018
# Processing folder: D:\dataset\MSc DS\2032019
# Error processing D:\dataset\MSc DS\2032019\mark_sheet_2_2032019.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032019\mark_sheet_7_2032019.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032019\mark_sheet_8_2032019.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032019\mark_sheet_9_2032019.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032020
# Error processing D:\dataset\MSc DS\2032020\aadhar_back_2032020.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032020\aadhar_front_2032020.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032020\id_card_front_2032020.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032021
# Processing folder: D:\dataset\MSc DS\2032022
# Processing folder: D:\dataset\MSc DS\2032023
# Error processing D:\dataset\MSc DS\2032023\aadhar_front_2032023.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032023\id_card_front_2032023.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032023\pan_card_2032023.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032024
# Error processing D:\dataset\MSc DS\2032024\aadhar_back_2032024.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032025
# Error processing D:\dataset\MSc DS\2032025\aadhar_back_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\aadhar_front_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\birth_certificate_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\id_card_back_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\id_card_front_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_1_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_3_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_4_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_5_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_6_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_7_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_8_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032025\mark_sheet_9_2032025.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032026
# Processing folder: D:\dataset\MSc DS\2032027
# Error processing D:\dataset\MSc DS\2032027\aadhar_back_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\aadhar_front_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\birth_certificate_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\id_card_back_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\id_card_front_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_1_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_3_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_4_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_5_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_6_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_7_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\mark_sheet_9_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032027\pan_card_2032027.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032028
# Processing folder: D:\dataset\MSc DS\2032030
# Error processing D:\dataset\MSc DS\2032030\aadhar_back_2032030.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032030\aadhar_front_2032030.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032031
# Processing folder: D:\dataset\MSc DS\2032032
# Processing folder: D:\dataset\MSc DS\2032033
# Error processing D:\dataset\MSc DS\2032033\aadhar_back_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\aadhar_front_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\birth_certificate_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\id_card_back_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\id_card_front_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_1_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_2_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_3_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_4_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_5_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_6_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_7_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_8_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\mark_sheet_9_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032033\pan_card_2032033.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032034
# Error processing D:\dataset\MSc DS\2032034\aadhar_back_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\aadhar_front_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\birth_certificate_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\id_card_back_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\id_card_front_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\mark_sheet_1_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\mark_sheet_3_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\mark_sheet_4_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\mark_sheet_5_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032034\mark_sheet_6_2032034.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032035
# Error processing D:\dataset\MSc DS\2032035\mark_sheet_9_2032035.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032036
# Error processing D:\dataset\MSc DS\2032036\aadhar_back_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\aadhar_front_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\birth_certificate_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\id_card_back_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\id_card_front_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_1_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_2_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_3_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_4_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_5_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_6_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_7_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_8_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032036\mark_sheet_9_2032036.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032037
# Error processing D:\dataset\MSc DS\2032037\mark_sheet_2_2032037.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032037\mark_sheet_8_2032037.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032037\mark_sheet_9_2032037.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032037\pan_card_2032037.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032038
# Error processing D:\dataset\MSc DS\2032038\aadhar_back_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\aadhar_front_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\birth_certificate_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\mark_sheet_1_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\mark_sheet_3_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\mark_sheet_4_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\mark_sheet_5_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\mark_sheet_6_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032038\pan_card_2032038.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032040
# Error processing D:\dataset\MSc DS\2032040\4 _2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\aadhar_back_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\aadhar_front_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\birth_certificate_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\id_card_back_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_1_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_2_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_3_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_4_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_5_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_6_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_7_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_8_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032040\mark_sheet_9_2032040.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032041
# Error processing D:\dataset\MSc DS\2032041\aadhar_back_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\aadhar_front_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\birth_certificate_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\id_card_back_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\id_card_front_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_1_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_2_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_3_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_4_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_5_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_6_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_7_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_8_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\mark_sheet_9_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032041\pan_card_2032041.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032042
# Processing folder: D:\dataset\MSc DS\2032043
# Processing folder: D:\dataset\MSc DS\2032044
# Error processing D:\dataset\MSc DS\2032044\aadhar_back_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\aadhar_front_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\birth_certificate_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\id_card_back_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\id_card_front_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_1_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_2_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_3_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_4_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_5_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_6_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_7_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_8_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032044\mark_sheet_9_2032044.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032045
# Error processing D:\dataset\MSc DS\2032045\birth_certificate_2032045.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032045\mark_sheet_7_2032045.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032045\mark_sheet_8_2032045.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032045\mark_sheet_9_2032045.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032045\pan_card_2032045.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032046
# Processing folder: D:\dataset\MSc DS\2032047
# Error processing D:\dataset\MSc DS\2032047\birth_certificate_2032047.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032048
# Error processing D:\dataset\MSc DS\2032048\pan_card_2032048.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032049
# Error processing D:\dataset\MSc DS\2032049\aadhar_back_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\aadhar_front_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\birth_certificate_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\id_card_back_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\id_card_front_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_1_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_2_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_3_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_4_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_5_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_6_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_7_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_8_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error processing D:\dataset\MSc DS\2032049\mark_sheet_9_2032049.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032050
# Error processing D:\dataset\MSc DS\2032050\aadhar_back_2032050.pdf: Unable to get page count. Is poppler installed and in PATH?
# Processing folder: D:\dataset\MSc DS\2032051
# Error processing D:\dataset\MSc DS\2032051\pan_card_2032051.pdf: Unable to get page count. Is poppler installed and in PATH?
# Data has been saved to D:\dataset\MSc DS\extracted_texts.csv

# %%
pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.3-py3-none-any.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      -------------------------------------- 42.0/42.0 kB 992.3 kB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\gokul01\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber) (9.2.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\gokul01\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (2.0.6)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\gokul01\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\gokul01\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\gokul01\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Downloading pdfplumber-0.11.3-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.2 kB ? eta -:--:--
#    ---------------------------------------- 59.2/59.2 kB 1.6 MB/s eta 0:00:00
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.3 pypdfium2-4.30.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

# Define the folder path
folder_path = 'D:/dataset/MSc DS/2032051'

# Extract the folder number from the folder name
folder_number = os.path.basename(folder_path)

# List all files in the folder
files = os.listdir(folder_path)

# Rename each file by appending the folder number to the filename
for file_name in files:
    # Construct the old file path
    old_file_path = os.path.join(folder_path, file_name)
    
    # Split the file name and extension
    name, ext = os.path.splitext(file_name)
    
    # Create the new file name with the folder number appended
    new_file_name = f"{name}_{folder_number}{ext}"
    
    # Construct the new file path
    new_file_path = os.path.join(folder_path, new_file_name)
    
    # Rename the file
    os.rename(old_file_path, new_file_path)

print("Files have been renamed successfully.")
# Out:
# Files have been renamed successfully.

# %%
import os
import pdfplumber
import pandas as pd

# Specify the path to the folder containing resumes
folder_path = r"D:\dataset\RESUMES  (File responses)"

def extract_text_from_pdf(pdf_path):
    text = ''
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() or ''
    return text

def extract_label_from_filename(filename):
    base_name = os.path.splitext(filename)[0]
    # Extract the label based on your specific filename format
    parts = base_name.split('_')
    if len(parts) > 1:
        return parts[0]  # Return the document type
    return "Unknown"

def process_folder(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.pdf'):
            file_path = os.path.join(folder_path, file_name)
            extracted_text = extract_text_from_pdf(file_path)
            label = extract_label_from_filename(file_name)
            data.append({"Document Filename": file_name, "Text": extracted_text, "Label": label})
    return data

# Process the specified folder
all_data = process_folder(folder_path)

# Create DataFrame and save to CSV
df = pd.DataFrame(all_data)
df.to_csv("resume.csv", index=False)

# %%
import pandas as pd

# Paths to the CSV files
csv_file1 = r"D:\Mini Projects\AI_Legal_Document_Analyzer\data\extracted_texts.csv"
csv_file2 = r"D:\Mini Projects\AI_Legal_Document_Analyzer\data\resume.csv"

# Load the CSV files into DataFrames
df1 = pd.read_csv(csv_file1)
df2 = pd.read_csv(csv_file2)

# Concatenate the DataFrames
merged_df = pd.concat([df1, df2], ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_file.csv', index=False)
